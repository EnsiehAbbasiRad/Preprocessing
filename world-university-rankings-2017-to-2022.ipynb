# %%
import numpy as np
#import pandas as pd
import matplotlib.pyplot as plt

# %%
# read DataSet
data = pd.read_csv("qs-world-university-rankings-2017-to-2022-V2.csv")
data
# Out:
#                                         university  year rank_display  score  \
# 0     Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                              Stanford University  2017            2   98.7
# 2                               Harvard University  2017            3   98.3
# 3                          University of Cambridge  2017            4   97.2
# 4     California Institute of Technology (Caltech)  2017            5   96.9
# ...                                            ...   ...          ...    ...
# 6477                           Université de Tunis  2022         1201    NaN
# 6478                  Université de Tunis El Manar  2022         1201    NaN
# 6479                            Yarmouk University  2022         1201    NaN
# 6480                   Yildiz Technical University  2022         1201    NaN
# 6481                            Zagazig University  2022         1201    NaN
#
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                         university  year rank_display  score  \
# 0     Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                              Stanford University  2017            2   98.7
# 2                               Harvard University  2017            3   98.3
# 3                          University of Cambridge  2017            4   97.2
# 4     California Institute of Technology (Caltech)  2017            5   96.9
# ...                                            ...   ...          ...    ...
# 6477                           Université de Tunis  2022         1201    NaN
# 6478                  Université de Tunis El Manar  2022         1201    NaN
# 6479                            Yarmouk University  2022         1201    NaN
# 6480                   Yildiz Technical University  2022         1201    NaN
# 6481                            Zagazig University  2022         1201    NaN
#
# ...

# %%
df.describe()
# Out:
#               year        score  student_faculty_ratio
# count  6482.000000  2820.000000            6407.000000
# mean   2019.693613    46.595532              13.264554
# std       1.716683    18.813110               6.604294
# min    2017.000000    23.500000               1.000000
# 25%    2018.000000    31.800000               9.000000
# 50%    2020.000000    40.600000              12.000000
# 75%    2021.000000    58.025000              17.000000
# max    2022.000000   100.000000              67.000000

# %%
df.describe (include='all')
# Out:
#                                           university         year  \
# count                                           6482  6482.000000
# unique                                          1368          NaN
# top     Massachusetts Institute of Technology (MIT)           NaN
# freq                                               6          NaN
# mean                                             NaN  2019.693613
# std                                              NaN     1.716683
# min                                              NaN  2017.000000
# 25%                                              NaN  2018.000000
# 50%                                              NaN  2020.000000
# 75%                                              NaN  2021.000000
# max                                              NaN  2022.000000
#
#        rank_display        score  \
# count          6414  2820.000000
# unique          517          NaN
# top        801-1000          NaN
# freq            954          NaN
# ...

# %%
np.shape(df)
# Out:
# (6482, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6482 entries, 0 to 6481
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   university              6482 non-null   object
#  1   year                    6482 non-null   int64
#  2   rank_display            6414 non-null   object
#  3   score                   2820 non-null   float64
#  4   link                    6482 non-null   object
#  5   country                 6482 non-null   object
#  6   city                    6304 non-null   object
#  7   region                  6482 non-null   object
#  8   logo                    6482 non-null   object
#  9   type                    6470 non-null   object
#  10  research_output         6480 non-null   object
#  11  student_faculty_ratio   6407 non-null   float64
#  12  international_students  6318 non-null   object
#  13  size                    6480 non-null   object
# ...

# %%
df2=df.dropna()
df2
# Out:
#                                         university  year rank_display  score  \
# 0     Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                              Stanford University  2017            2   98.7
# 2                               Harvard University  2017            3   98.3
# 3                          University of Cambridge  2017            4   97.2
# 4     California Institute of Technology (Caltech)  2017            5   96.9
# ...                                            ...   ...          ...    ...
# 5678                           Dongguk University   2022          494   24.1
# 5679                         Iowa State University  2022          494   24.1
# 5680                             Sogang University  2022          494   24.1
# 5681              University of Rome "Tor Vergata"  2022          494   24.1
# 5682                               York University  2022          494   24.1
#
# ...

# %%
df3=df2.head(20)
df3
# Out:
#                                            university  year rank_display  \
# 0        Massachusetts Institute of Technology (MIT)   2017            1
# 1                                 Stanford University  2017            2
# 2                                  Harvard University  2017            3
# 3                             University of Cambridge  2017            4
# 4        California Institute of Technology (Caltech)  2017            5
# 5                                University of Oxford  2017            6
# 6                                                 UCL  2017            7
# 7   ETH Zurich - Swiss Federal Institute of Techno...  2017            8
# 8                             Imperial College London  2017            9
# 9                               University of Chicago  2017           10
# 10                               Princeton University  2017           11
# 11             National University of Singapore (NUS)  2017           12
# ...

# %%
#df = df.iloc[:100,:]
plt.figure(figsize = (10,8))
#df5=df4.iloc[90:95]
plt.xticks(rotation=90)
plt.hist(df3['type'], color="orange", bins=50)
#plt.title ("Rating VS Number_Of_Pages", fontsize = 30, color="green")
plt.xlabel('type' , fontsize = 16,color="red")
plt.ylabel('amount' , fontsize = 16, color="red")
plt.grid()
plt.show()

# %%
#df = df.iloc[:100,:]
plt.figure(figsize = (10,8))
#df5=df4.iloc[90:95]
plt.xticks(rotation=90)
plt.hist(df3['size'], color="orange", bins=50)
#plt.title ("Rating VS Number_Of_Pages", fontsize = 30, color="green")
plt.xlabel('size' , fontsize = 16,color="red")
plt.ylabel('amount' , fontsize = 16, color="red")
plt.grid()
plt.show()

# %%
#df = df.iloc[:100,:]
#plt.figure(figsize = (10,8))
#df5=df4.iloc[90:95]
plt.xticks(rotation=90)
plt.hist(df3['region'], color="orange", bins=50)
#plt.title ("Rating VS Number_Of_Pages", fontsize = 30, color="green")
plt.xlabel('faculty_count' , fontsize = 18,color="red")
plt.ylabel('amount' , fontsize = 18, color="red")
plt.grid()
plt.show()

# %%
df3=df2.head(120)
plt.figure(figsize = (10,5))
plt.xticks(rotation=90)
plt.hist(df3['country'], color="orange", bins=50)
#plt.title ("Rating VS Number_Of_Pages", fontsize = 30, color="green")
plt.xlabel('country' , fontsize = 18,color="red")
plt.ylabel('amount' , fontsize = 18, color="red")
plt.grid()
plt.show()

# %%
df3=df2.head(120)
plt.figure(figsize = (30,8))
plt.xticks(rotation=90)
plt.hist(df3['faculty_count'], color="orange", bins=50)
#plt.title ("Rating VS Number_Of_Pages", fontsize = 30, color="green")
plt.xlabel('faculty_count' , fontsize = 16,color="red")
plt.ylabel('amount' , fontsize = 16, color="red")
plt.grid()
plt.show()

# %%
#The largest number of faculty
plt.figure(figsize = (14,5))
df3=df2.head(20)
plt.scatter(df3['faculty_count'],df3['university'],color="orange")
plt.xlabel('faculty_count', fontsize = 18, color="red")
plt.ylabel('university', fontsize = 18, color="red")
plt.grid()
#plt.savefig("plot1.png")
plt.show()

# %%
#df8 = df3.sort_values(by=['size'],ascending=True)

# %%
#In terms of area
plt.figure(figsize = (10,8))

plt.scatter(df3['size'],df3['university'], color="orange")
plt.xlabel('size', fontsize = 18, color="red")
plt.ylabel('university' , fontsize = 18, color="red")
plt.grid()
plt.savefig("plot1.png")
plt.show()

# %%
df6 = df3.sort_values(by=['score'],ascending=False)

# %%
plt.figure(figsize = (20,10))

plt.scatter(df6['score'],df6['university'])
plt.xlabel('score')
plt.ylabel('university')
plt.grid()
plt.savefig("plot1.png")
plt.show()

# %%
df6 = df3.sort_values(by=['rank_display'],ascending =True)

# %%
#good

plt.figure(figsize = (10,8))
df6 = df3.sort_values(by=['rank_display'],ascending =True)
plt.scatter(df6['rank_display'],df6['university'],color="orange")
plt.xlabel('rank_display',fontsize = 18, color="red")
plt.ylabel('university',fontsize = 18, color="red")
plt.grid()
plt.savefig("plot1.png")
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.scatter(df2['research_output'],df2['year'], color="blue")
plt.title ("research VS year", fontsize = 30, color="green")
plt.xlabel('research_output' , fontsize = 16,color="red")
plt.ylabel('year' , fontsize = 16, color="red")
plt.legend(['Show research'])
plt.grid()
plt.show()

# %%
# The largest number of international students
plt.figure(figsize = (12,8))
plt.xticks(rotation=90)
plt.scatter(df3['university'],df3['international_students'], color="blue")
plt.title ("research VS year", fontsize = 30, color="green")
plt.xlabel('university' , fontsize = 16,color="red")
plt.ylabel('international_students' , fontsize = 16, color="red")
plt.legend(['Show research'])
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,5))

df9=df2.head(20)

plt.xticks(rotation=90)
plt.scatter(df9['student_faculty_ratio'],df9['university'], color="orange")
plt.xlabel('student_faculty_ratio' , fontsize = 18,color="red")
plt.ylabel('university' , fontsize = 18, color="red")
#plt.legend(['Show research'])
plt.grid()
plt.show()

# %%
plt.figure(figsize = (12,5))

plt.xticks(rotation=90)
#y_positions = range (len(df3['university']))

plt.bar(y_positions,df3['rank_display'],color="orange")
plt.xticks(y_positions,df3['university'])

#plt.bar(y_positions,df3['university'])
#plt.xticks(y_positions,df3['rank_display'])

#plt.title ("Rating VS Type", fontsize = 30, color="green")
plt.xlabel('university' , fontsize = 16,color="red")
plt.ylabel('rank_display' , fontsize = 16, color="red")

plt.show()

# %%
df9=df2.head(20)
plt.figure(figsize = (10,8))
plt.title ("university VS type", fontsize = 20, color="green")
plt.bar(df9['type'],df9['university'])
plt.xlabel('type', fontsize = 20, color="red")
plt.ylabel('university', fontsize = 20, color="red")
plt.savefig("1universityVStype.png")
plt.show()

# %%
df9=df2.head(20)
plt.figure(figsize = (10,8))
#df3=df2.iloc[70:90]
plt.bar(df9['score'],df9['university'],color="orange")
plt.xlabel('score' , fontsize = 16, color="red")
plt.ylabel('university' , fontsize = 16, color="red")
plt.show()

# %%
df9=df2.head(20)
plt.figure(figsize = (10,8))
plt.title ("university VS type", fontsize = 20, color="green")
plt.bar(df9['type'],df9['university'],color="orange")
plt.xlabel('type', fontsize = 18, color="red")
plt.ylabel('university', fontsize = 18, color="red")

plt.show()

# %%
plt.figure(figsize = (100,10))
df2.groupby(df2['region']).sum().plot(kind='pie', y='score', autopct='%1.0f%%',radius=2)
# Out:
# <AxesSubplot:ylabel='score'>

# %%
plt.figure(figsize = (100,10))
df3.groupby(df2['research_output']).sum().plot(
    kind='pie', y='score', autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='score'>
